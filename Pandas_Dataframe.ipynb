# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\rahul\Downloads\Retail_dataset.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1037/1943539717.py in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 df = pd.read_csv(r"C:\Users\rahul\Downloads\Retail_dataset.csv")
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\rahul\\Downloads\\Retail_dataset.csv'

# %% [markdown]
# Q1. Creating a DataFrame
#
# Create a Pandas DataFrame using a Python dictionary with the following columns:
#
# Product
#
# Region
#
# Sales
#
# Quantity
#
#
# Add at least 5 rows of sample data and display the DataFrame.

# %%
import pandas as pd

# Create a dictionary
data = {
    "Product": ["Laptop", "Mouse", "Keyboard", "Monitor", "Printer"],
    "Region": ["North", "South", "East", "West", "Central"],
    "Sales": [50000, 1500, 2500, 12000, 8000],
    "Quantity": [5, 20, 15, 8, 6]
}

# Create DataFrame
df = pd.DataFrame(data)

# Display DataFrame
print(df)
# Out:
#     Product   Region  Sales  Quantity
# 0    Laptop    North  50000         5
# 1     Mouse    South   1500        20
# 2  Keyboard     East   2500        15
# 3   Monitor     West  12000         8
# 4   Printer  Central   8000         6

# %% [markdown]
# Q2. Data Inspection
#
# Perform the following inspection tasks:
#
# Display the first 5 rows of the dataset.
#
# Display the last 5 rows.
#
# Show the structure of the dataset using info().
#
# Display the shape of the dataset.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q3. Column Selection
#
# Select and display only the following columns:
#
# Product
#
# Region
#
# Sales

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q4. Indexing using .loc Using .loc, perform the following:
# sing .loc, perform the following:
#
# 1.Display the row with index 10.
#
# 2.Display the Sales value of the row with index 20

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q5. Indexing using .iloc
#
# Using .iloc, display:
#
# The first 6 rows and first 4 columns.
#
# The Sales value from the 3rd row.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q6. Row Slicing
#
# Display:
#
# The first 10 rows of the dataset.
#
# Rows 15 to 25.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q7. Filtering Data
#
# Filter the dataset to display:
#
# Rows where Region = "East".
#
# Rows where Sales > 1500.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q8. Multiple Condition Filtering
#
# Display rows where:
#
# Region is West
#
# Sales is greater than 1200

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q9. Descriptive Statistics
#
# Generate summary statistics using:
#
# describe()
#
# From the result identify:
#
# Mean sales value
#
# Maximum quantity sold
#
# Minimum sales value

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q10. Aggregation Analysis
#
# Using the Sales column, calculate:
#
# Total sales
#
# Average sales
#
# Maximum sales
#
# Minimum sales

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
